# %%
import graph_tool.all as gt
from packing_coloring.graph_generator import *
from packing_coloring.utils import *
from packing_coloring.algorithms.problem import *

from packing_coloring.algorithms.perturbative.ils_algo import *
from packing_coloring.algorithms.constructive.rlf_algo import rlf_algorithm
from packing_coloring.algorithms.perturbative.tabupackcol import partial_pack_col

import numpy as np
import pandas as pd
import igraph
np.set_printoptions(threshold=np.nan)

from IPython.html.widgets import interactive
from IPython.display import display
from os import listdir
from os.path import join, isfile
from pylab import get_cmap
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
def square_grid_ils_pcoloring(size, file_name="test.pdf", out_size=(250,250), font_size=22):
    g = gt.lattice([size, size])
    dist_mat = get_distance_matrix(g)
    prob = GraphProblem(dist_mat)

    p_col1 = ils_algorithm(prob, rlf_algorithm, partial_pack_col)

    pos = gt.sfdp_layout(g, max_iter=1)
    for i,v in enumerate(g.vertices()):
        pos[v][0] = np.floor(i/size)*2
        pos[v][1] = (i%size)*2

    max_col = p_col1.get_max_col()
    col = [c/max_col for c in p_col1]
    col_v = g.new_vertex_property("float")
    col_v.a = np.array(col)

    text_v = g.new_vertex_property("int")
    text_v.a = p_col1.pack_col.astype(int)

    gt.graph_draw(g, pos=pos, vertex_text=text_v, vertex_font_size=font_size, output_size=out_size, vertex_fill_color=col_v, vcmap=get_cmap("Set1"), output=file_name)
    gt.graph_draw(g, pos=pos, vertex_text=text_v, vertex_font_size=font_size, vertex_fill_color=col_v, vcmap=get_cmap("Set1"), inline=True)

    print(np.max(p_col1))
    print(p_col1)
    
def random_ts_pcoloring(file_name="test.pdf", out_size=(250,250), font_size=16):
    g = gt.load_graph("instances/dot_format/random.dot")
    dist_mat = get_distance_matrix(g)
    prob = GraphProblem(dist_mat)

    p_col1 = tabu_pack_col(prob, k_count=5, tt_a=10, tt_d=0.6, max_iter=1000)

    pos = gt.sfdp_layout(g, cooling_step=0.95, epsilon=1e-2)
    max_col = p_col1.get_max_col()
    col = [c/max_col for c in p_col1]
    col_v = g.new_vertex_property("float")
    col_v.a = np.array(col)

    text_v = g.new_vertex_property("int")
    text_v.a = p_col1.pack_col.astype(int)

    gt.graph_draw(g, pos=pos, vertex_text=text_v, vertex_font_size=font_size, output_size=out_size, vertex_fill_color=col_v, vcmap=get_cmap("Set1"), output=file_name)
    gt.graph_draw(g, pos=pos, vertex_text=text_v, vertex_font_size=font_size, vertex_fill_color=col_v, vcmap=get_cmap("Set1"), inline=True)

    print(np.max(p_col1))
    print(p_col1)

# %% [markdown]
# # Packing coloration of 3x3 grid using TS

# %%
square_grid_ils_pcoloring(3, file_name="../Report/Pictures/ILS_G3-3.pdf", out_size=(105, 150))
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ccd0228de8d1> in <module>()
# ----> 1 square_grid_ils_pcoloring(3, file_name="../Report/Pictures/ILS_G3-3.pdf", out_size=(105, 150))
#
# <ipython-input-2-77a39510944e> in square_grid_ils_pcoloring(size, file_name, out_size, font_size)
#       4     prob = GraphProblem(dist_mat)
#       5
# ----> 6     p_col1 = ils_algorithm(prob, rlf_algorithm, partial_pack_col)
#       7
#       8     pos = gt.sfdp_layout(g, max_iter=1)
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/perturbative/ils_algo.py in ils_algorithm(prob, heuristic, local_search, sol, max_iter)
#      39
#      40     while max_iter > 0:
# ---> 41         new_sol = pertub(prob, sol, heuristic, local_search)
#      42         new_sol = local_search(prob, sol=new_sol, k_count=1, max_iter=100, duration=5)
#      43         new_score = new_sol.get_max_col()
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/perturbative/ils_algo.py in pertub(prob, sol, heuristic, local_search)
#      24     new_prob = GraphProblem(adj_mat)
#      25     new_sol = heuristic(new_prob)
# ---> 26     new_sol = local_search(new_prob, sol=new_sol, duration=5)
#      27     return greedy_algorithm(prob, new_sol.get_greedy_order())
#      28
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/perturbative/tabupackcol.py in partial_pack_col(prob, k_count, sol, tt_a, tt_d, max_iter, duration)
#     184     while count < k_count:
#     185         # print(k_col)
# --> 186         new_sol = partial_kpack_col(prob, k_col, new_sol, tt_a, tt_d, max_iter)
#     187         if new_sol.get_max_col() == k_col:
#     188             k_lim = k_col
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/perturbative/tabupackcol.py in partial_kpack_col(prob, k_col, sol, tt_a, tt_d, max_iter)
#     147         vertex, col = best_i_swap(prob, sol, best_score, colors, tabu_list)
#     148
# --> 149         prev_colored = (sol == col)
#     150         sol = assign_col(prob, sol, col, vertex)
#     151         score = sol.count_uncolored()
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/solution.py in __eq__(self, val)
#      56     # Mutable object so, no __hash__ function will be defined
#      57     def __eq__(self, val):
# ---> 58         if np.issubdtype(type(val), np.integer):
#      59             return self.pack_col == val
#      60         elif type(val) is PackColSolution:
#
# /usr/lib/python3.4/site-packages/numpy/core/numerictypes.py in issubdtype(arg1, arg2)
#     761     """
#     762     if issubclass_(arg2, generic):
# --> 763         return issubclass(dtype(arg1).type, arg2)
#     764     mro = dtype(arg2).type.mro()
#     765     if len(mro) > 1:
#
# KeyboardInterrupt:

# %% [markdown]
# # Packing coloration of 24x24 grid using TS

# %%
square_grid_ils_pcoloring(24, file_name="../Report/Pictures/ILS_G24-24.pdf", out_size=(500, 500), font_size=15)

# %%
random_ts_pcoloring(file_name="../Report/Pictures/TS_Random.pdf", out_size=(250,250), font_size=16)
# Out:
# 12
# 13
# [ 1  3  1  5  4  2  1  6  1  4  1  7  8  9  1  2  1 10  1 11  2  3  1  2  1
#   2  1  3 12 13  1]
