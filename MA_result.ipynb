# %%
import graph_tool.all as gt
from packing_coloring.graph_generator import *
from packing_coloring.utils import *
from packing_coloring.algorithms.problem import *

from packing_coloring.algorithms.constructive.rlf_algo import *
from packing_coloring.algorithms.constructive.swo_algo import *
from packing_coloring.algorithms.perturbative.genetic_algo import *
from packing_coloring.algorithms.perturbative.tabupackcol import *

import numpy as np
import pandas as pd
import igraph
np.set_printoptions(threshold=np.nan)

from IPython.html.widgets import interactive
from IPython.display import display
from os import listdir
from os.path import join, isfile
from pylab import get_cmap
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
def square_grid_ma_pcoloring(size, file_name="test.pdf", out_size=(250,250), font_size=22):
    g = gt.lattice([size, size])
    dist_mat = get_distance_matrix(g)
    prob = GraphProblem(dist_mat)
    
    eval_func = lambda a: a.get_sum()
    p_col1 = hybrid_algorithm(prob, partial_pack_col, 10, swo_algorithm, eval_func, 10)

    pos = gt.sfdp_layout(g, max_iter=1)
    for i,v in enumerate(g.vertices()):
        pos[v][0] = np.floor(i/size)*2
        pos[v][1] = (i%size)*2

    max_col = p_col1.get_max_col()
    col = [c/max_col for c in p_col1]
    col_v = g.new_vertex_property("float")
    col_v.a = np.array(col)

    text_v = g.new_vertex_property("int")
    text_v.a = p_col1.pack_col.astype(int)

    gt.graph_draw(g, pos=pos, vertex_text=text_v, vertex_font_size=font_size, output_size=out_size, vertex_fill_color=col_v, vcmap=get_cmap("Set1"), output=file_name)
    gt.graph_draw(g, pos=pos, vertex_text=text_v, vertex_font_size=font_size, vertex_fill_color=col_v, vcmap=get_cmap("Set1"), inline=True)

    print(np.max(p_col1))
    print(p_col1)
    
def random_ma_pcoloring(file_name="test.pdf", out_size=(250,250), font_size=16):
    g = gt.load_graph("instances/dot_format/random.dot")
    dist_mat = get_distance_matrix(g)
    prob = GraphProblem(dist_mat)

    eval_func = lambda a: a.get_sum()
    p_col1 = hybrid_algorithm(prob, partial_pack_col, 10, swo_algorithm, eval_func, 10)
    
    pos = gt.sfdp_layout(g, cooling_step=0.95, epsilon=1e-2)
    max_col = p_col1.get_max_col()
    col = [c/max_col for c in p_col1]
    col_v = g.new_vertex_property("float")
    col_v.a = np.array(col)

    text_v = g.new_vertex_property("int")
    text_v.a = p_col1.pack_col.astype(int)

    gt.graph_draw(g, pos=pos, vertex_text=text_v, vertex_font_size=font_size, output_size=out_size, vertex_fill_color=col_v, vcmap=get_cmap("Set1"), output=file_name)
    gt.graph_draw(g, pos=pos, vertex_text=text_v, vertex_font_size=font_size, vertex_fill_color=col_v, vcmap=get_cmap("Set1"), inline=True)

    print(np.max(p_col1))
    print(p_col1)

# %% [markdown]
# # Packing coloration of 3x3 grid using TS

# %%
square_grid_ma_pcoloring(3, file_name="../Report/Pictures/MA_G3-3.pdf", out_size=(105, 150), font_size=12)
# Out:
# init candidate # 0 : 5
# init candidate # 1 : 5
# init candidate # 2 : 4
# init candidate # 3 : 4
# init candidate # 4 : 4
# init candidate # 5 : 5
# init candidate # 6 : 4
# init candidate # 7 : 5
# init candidate # 8 : 5
# init candidate # 9 : 4
# individu # 0 's quality: 4
# individu # 1 's quality: 4
# individu # 2 's quality: 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-47c2cb8b5545> in <module>()
# ----> 1 square_grid_ma_pcoloring(3, file_name="../Report/Pictures/MA_G3-3.pdf", out_size=(105, 150), font_size=12)
#
# <ipython-input-2-2094b79c4929> in square_grid_ma_pcoloring(size, file_name, out_size, font_size)
#       5
#       6     eval_func = lambda a: a.get_sum()
# ----> 7     p_col1 = hybrid_algorithm(prob, partial_pack_col, 10, swo_algorithm, eval_func, 10)
#       8
#       9     pos = gt.sfdp_layout(g, max_iter=1)
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/perturbative/genetic_algo.py in hybrid_algorithm(prob, local_search, pop_size, init_heur, eval_func, max_iter)
#     135     pop = generate_population(prob, init_heur, pop_size)
#     136     for i, indiv in enumerate(pop):
# --> 137         pop[i] = local_search(prob, sol=indiv, duration=5)
#     138         print("individu #", i, "'s quality:", pop[i].get_max_col())
#     139
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/perturbative/tabupackcol.py in partial_pack_col(prob, k_count, sol, tt_a, tt_d, max_iter, duration)
#     184     while count < k_count:
#     185         # print(k_col)
# --> 186         new_sol = partial_kpack_col(prob, k_col, new_sol, tt_a, tt_d, max_iter)
#     187         if new_sol.get_max_col() == k_col:
#     188             k_lim = k_col
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/perturbative/tabupackcol.py in partial_kpack_col(prob, k_col, sol, tt_a, tt_d, max_iter)
#     145     best_score = score
#     146     while score > 0 and max_iter > 0:
# --> 147         vertex, col = best_i_swap(prob, sol, best_score, colors, tabu_list)
#     148
#     149         prev_colored = (sol == col)
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/search_space/partial_valide_col.py in best_i_swap(prob, sol, the_best_score, colors, tabu_list)
#      92     for v in vertices[sol.uncolored()]:
#      93         for col in colors:
# ---> 94             new_sol = assign_col(prob, sol, col, v)
#      95             new_score = new_sol.count_uncolored()
#      96             new_sum = new_sol.get_sum()
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/search_space/partial_valide_col.py in assign_col(prob, sol, k_col, v)
#      76     new_sol = sol.copy()
#      77     v_conflict = np.logical_and(
# ---> 78             new_sol.pack_col == k_col, prob[v] <= k_col)
#      79     new_sol.pack_col[v_conflict] = 0
#      80     new_sol[v] = k_col
#
# /home/dollars/Documents/Cours/MA_2/Memo-f-508/packing_coloring_app/packing_coloring/algorithms/problem.py in __getitem__(self, key)
#      48     def __getitem__(self, key):
#      49         try:
# ---> 50             return self.dist_matrix[key].A1
#      51         except IndexError:
#      52             raise IndexError("index out of bound: {0}".format(key))
#
# /usr/lib/python3.4/site-packages/numpy/matrixlib/defmatrix.py in __getitem__(self, index)
#     333                 out.shape = (sh, 1)
#     334             else:
# --> 335                 out.shape = (1, sh)
#     336         return out
#     337
#
# /usr/lib/python3.4/site-packages/numpy/matrixlib/defmatrix.py in __array_finalize__(self, obj)
#     288         return ret
#     289
# --> 290     def __array_finalize__(self, obj):
#     291         self._getitem = False
#     292         if (isinstance(obj, matrix) and obj._getitem): return
#
# KeyboardInterrupt:

# %% [markdown]
# # Packing coloration of 24x24 grid using MA

# %%
square_grid_ma_pcoloring(24, file_name="../Report/Pictures/MA_G24-24.pdf", out_size=(500, 500), font_size=15)

# %%
random_ma_pcoloring(file_name="../Report/Pictures/MA_Random.pdf", out_size=(250,250), font_size=16)
# Out:
# init candidate # 0 : 13
# init candidate # 1 : 15
# init candidate # 2 : 15
# init candidate # 3 : 16
# init candidate # 4 : 16
# init candidate # 5 : 17
# init candidate # 6 : 15
# init candidate # 7 : 14
# init candidate # 8 : 19
# init candidate # 9 : 17
# individu # 0 's quality: 12
# individu # 1 's quality: 13
# individu # 2 's quality: 11
# individu # 3 's quality: 12
# individu # 4 's quality: 12
# individu # 5 's quality: 11
# individu # 6 's quality: 13
# individu # 7 's quality: 12
# individu # 8 's quality: 14
# individu # 9 's quality: 15
# [[ 11 104]
#  [ 11 104]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 113]
#  [ 13 120]
#  [ 13 121]
#  [ 14 130]
#  [ 15 148]]
# generation # 10
# parent1: 6 -> 13
# parent2: 4 -> 12
# child: 13
# improved child:  12
# mutated child:  16
# improved mutated child:  12
# [[ 11 104]
#  [ 11 104]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 113]
#  [ 13 120]
#  [ 13 121]
#  [ 14 130]
#  [ 15 148]]
#
# generation # 9
# parent1: 5 -> 12
# parent2: 4 -> 12
# child: 13
# improved child:  12
# mutated child:  14
# improved mutated child:  12
# [[ 11 104]
#  [ 11 104]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 113]
#  [ 13 120]
#  [ 13 121]]
#
# generation # 8
# parent1: 0 -> 11
# parent2: 2 -> 12
# child: 14
# improved child:  12
# mutated child:  16
# improved mutated child:  12
# [[ 11 104]
#  [ 11 104]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 113]]
#
# generation # 7
# parent1: 3 -> 12
# parent2: 7 -> 12
# child: 13
# improved child:  12
# mutated child:  13
# improved mutated child:  13
# [[ 11 104]
#  [ 11 104]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 113]
#  [ 13 117]]
#
# generation # 6
# parent1: 8 -> 12
# parent2: 4 -> 12
# child: 14
# improved child:  11
# mutated child:  14
# improved mutated child:  12
# [[ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 12 111]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]]
#
# generation # 5
# parent1: 3 -> 12
# parent2: 1 -> 11
# child: 11
# improved child:  11
# mutated child:  14
# improved mutated child:  13
# [[ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 12 111]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 13 122]]
#
# generation # 4
# parent1: 7 -> 12
# parent2: 1 -> 11
# child: 14
# improved child:  11
# mutated child:  14
# improved mutated child:  12
# [[ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 12 111]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]]
#
# generation # 3
# parent1: 4 -> 11
# parent2: 5 -> 12
# child: 12
# improved child:  12
# mutated child:  15
# improved mutated child:  11
# [[ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 12 111]
#  [ 12 111]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]
#  [ 12 112]]
#
# generation # 2
# parent1: 5 -> 11
# parent2: 2 -> 11
# child: 12
# improved child:  11
# mutated child:  14
# improved mutated child:  12
# [[ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 12 111]
#  [ 12 111]
#  [ 12 111]
#  [ 12 112]
#  [ 12 112]]
#
# generation # 1
# parent1: 1 -> 11
# parent2: 5 -> 11
# child: 11
# improved child:  11
# mutated child:  15
# improved mutated child:  13
# [[ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 11 104]
#  [ 12 111]
#  [ 12 111]
#  [ 12 111]
#  [ 13 122]]
# 11
# [ 4  9  1  8  1  3  1  7  2  5  1  1 10 11  1  3  1  6  1  2  2  3  2  4  1
#   1  5  4  2  1  1]
